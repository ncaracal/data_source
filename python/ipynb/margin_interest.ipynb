# %% [markdown]
# # Binance Cross-Margin Interest Rate History
#
# Reads the parquet written by `data_source -d marginInterestRate` and shows the
# latest rows.
#
# Source path: `$TRADE_DATA/binance/spot/marginInterestRate/{ASSET}/{ASSET}_marginInterestRate_all.parquet`

# %%
import os
from pathlib import Path
import pandas as pd

pd.set_option("display.max_rows", 100)
pd.set_option("display.width", 160)

# --- config ---
ASSET = "STORJ"   # change to STO, STORJ, ...
N = 30            # number of latest rows to show

TRADE_DATA = os.environ.get("TRADE_DATA", "/ndata/trade/data")
base = Path(TRADE_DATA) / "binance" / "spot" / "marginInterestRate"
print("Base:", base)
print("Available assets:", sorted(p.name for p in base.iterdir() if p.is_dir()))
# Out:
# Base: /ndata/trade/data/binance/spot/marginInterestRate
# Available assets: ['BADASSET', 'STO', 'STORJ']

# %%
path = base / ASSET / f"{ASSET}_marginInterestRate_all.parquet"
df = pd.read_parquet(path)
df["datetime"] = pd.to_datetime(df["timestamp"], unit="ms")
df = df.sort_values("timestamp").reset_index(drop=True)
print(f"{ASSET}: {len(df):,} rows, {df['datetime'].min()} .. {df['datetime'].max()}")
# Out:
# STORJ: 15,155 rows, 2020-09-22 15:51:00 .. 2026-05-16 10:00:00

# %%
# Latest N data rows
df.tail(N)
# Out:
#        asset      timestamp            datetime  daily_interest_rate  vip_level
# 15125  STORJ  1778590800000 2026-05-12 13:00:00             0.001243          0
# 15126  STORJ  1778594400000 2026-05-12 14:00:00             0.001264          0
# 15127  STORJ  1778605200000 2026-05-12 17:00:00             0.001175          0
# 15128  STORJ  1778608800000 2026-05-12 18:00:00             0.001233          0
# 15129  STORJ  1778612400000 2026-05-12 19:00:00             0.001205          0
# 15130  STORJ  1778630400000 2026-05-13 00:00:00             0.001190          0
# 15131  STORJ  1778634000000 2026-05-13 01:00:00             0.001221          0
# 15132  STORJ  1778641200000 2026-05-13 03:00:00             0.001249          0
# 15133  STORJ  1778644800000 2026-05-13 04:00:00             0.001230          0
# 15134  STORJ  1778648400000 2026-05-13 05:00:00             0.001252          0
# 15135  STORJ  1778662800000 2026-05-13 09:00:00             0.001230          0
# 15136  STORJ  1778666400000 2026-05-13 10:00:00             0.001215          0
# 15137  STORJ  1778716800000 2026-05-14 00:00:00             0.001215          0
# 15138  STORJ  1778731200000 2026-05-14 04:00:00             0.001243          0
# 15139  STORJ  1778734800000 2026-05-14 05:00:00             0.001338          0
# 15140  STORJ  1778803200000 2026-05-15 00:00:00             0.001338          0
# 15141  STORJ  1778814000000 2026-05-15 03:00:00             0.001235          0
# 15142  STORJ  1778817600000 2026-05-15 04:00:00             0.001219          0
# 15143  STORJ  1778828400000 2026-05-15 07:00:00             0.001239          0
# 15144  STORJ  1778857200000 2026-05-15 15:00:00             0.001215          0
# 15145  STORJ  1778860800000 2026-05-15 16:00:00             0.001823          0
# 15146  STORJ  1778864400000 2026-05-15 17:00:00             0.001989          0
# 15147  STORJ  1778868000000 2026-05-15 18:00:00             0.001709          0
# 15148  STORJ  1778871600000 2026-05-15 19:00:00             0.001659          0
# 15149  STORJ  1778889600000 2026-05-16 00:00:00             0.001676          0
# 15150  STORJ  1778896800000 2026-05-16 02:00:00             0.002397          0
# 15151  STORJ  1778900400000 2026-05-16 03:00:00             0.001962          0
# 15152  STORJ  1778904000000 2026-05-16 04:00:00             0.001908          0
# 15153  STORJ  1778922000000 2026-05-16 09:00:00             0.001877          0
# 15154  STORJ  1778925600000 2026-05-16 10:00:00             0.001909          0
